# %%
import pandas as pd
import json

# Read the JSON file into a string
with open('response_003a2491-9384-11ed-80a6-890591dec723.json') as f:
    json_string = f.read()

# Parse the JSON string into a Python object
data = json.loads(json_string)

# Convert the Python object into a pandas DataFrame
df = pd.read_json('response_003a2491-9384-11ed-80a6-890591dec723.json')

df = pd.json_normalize(data, record_path =['rows'])

df.head()
# Out:
#                                    uuid                         title  \
# 0  d053142e-f3ee-4ce3-a70f-2e41a41963ce        Total Rewards Director
# 1  d90a1b83-5175-4862-b6ab-6f88dc96b8e8                         False
# 2  1a2103dc-5091-49f5-ba07-19f8ecacb543                         False
# 3  801e091f-18ca-4f5e-a8a6-b77dae478cf8                    Hr Manager
# 4  e983ae47-a1fc-45e8-bdbd-328378dbee06  Hr And Accounting Specialist
#
#          jobFamily  level focusTag yearsOfExperience yearsAtCompany  \
# 0  Human Resources   None     None                22              1
# 1  Human Resources   None     None                22              3
# 2  Human Resources  False    False              5-10            2-4
# 3  Human Resources     P3     None                10              1
# 4  Human Resources   None     None                 1              1
#
#    yearsAtLevel                                          offerDate  \
# 0           1.0  Tue Jul 26 2022 17:13:58 GMT+0000 (Coordinated...
# 1           2.0  Sun Jul 24 2022 00:19:09 GMT+0000 (Coordinated...
# 2           2.0  Fri Jul 22 2022 17:11:28 GMT+0000 (Coordinated...
# 3           1.0  Fri Jul 22 2022 13:10:21 GMT+0000 (Coordinated...
# 4           1.0  Fri Jul 22 2022 13:07:15 GMT+0000 (Coordinated...
#
#             location  ... ethnicity         education  otherDetails  \
# 0       New York, NY  ...      None              None          None
# 1    Minneapolis, MN  ...      None              None           NaN
# 2  San Francisco, CA  ...      None              None           NaN
# 3  San Francisco, CA  ...      None              None          None
# 4       Waterloo, IA  ...     White  Bachelors degree          None
#
#    vestingSchedule  tags  companyInfo.registered  \
# 0             None  None                    True
# 1             None  None                     NaN
# 2             None  None                    True
# 3             None  None                    True
# 4             None  None                   False
#
#                               companyInfo.icon   companyInfo.name  \
# 0  https://logo.clearbit.com/thirtymadison.com     Thirty Madison
# 1                                          NaN                NaN
# 2        https://logo.clearbit.com/twitter.com            Twitter
# 3        https://logo.clearbit.com/mozilla.org            Mozilla
# 4                                         None  Building Products
#
#    companyInfo.slug companyInfo
# 0    thirty-madison         NaN
# 1               NaN       False
# 2           twitter         NaN
# 3           mozilla         NaN
# 4              None         NaN
#
# [5 rows x 35 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   uuid                      48 non-null     object
#  1   title                     48 non-null     object
#  2   jobFamily                 48 non-null     object
#  3   level                     35 non-null     object
#  4   focusTag                  12 non-null     object
#  5   yearsOfExperience         48 non-null     object
#  6   yearsAtCompany            48 non-null     object
#  7   yearsAtLevel              40 non-null     float64
#  8   offerDate                 48 non-null     object
#  9   location                  48 non-null     object
#  10  workArrangement           48 non-null     object
#  11  compPerspective           48 non-null     object
#  12  dmaId                     48 non-null     int64
#  13  countryId                 48 non-null     int64
#  14  exchangeRate              48 non-null     float64
#  15  baseSalary                48 non-null     float64
#  16  baseSalaryCurrency        48 non-null     object
#  17  totalCompensation         48 non-null     float64
#  18  avgAnnualStockGrantValue  15 non-null     float64
#  19  stockGrantCurrency        14 non-null     object
#  20  avgAnnualBonusValue       25 non-null     float64
#  21  bonusCurrency             25 non-null     object
#  22  salesComp                 0 non-null      object
#  23  negotiatedAmount          3 non-null      float64
#  24  gender                    30 non-null     object
#  25  ethnicity                 28 non-null     object
#  26  education                 28 non-null     object
#  27  otherDetails              1 non-null      object
#  28  vestingSchedule           3 non-null      object
#  29  tags                      9 non-null      object
#  30  companyInfo.registered    41 non-null     object
#  31  companyInfo.icon          26 non-null     object
#  32  companyInfo.name          41 non-null     object
#  33  companyInfo.slug          26 non-null     object
#  34  companyInfo               7 non-null      object
# dtypes: float64(7), int64(2), object(26)
# memory usage: 13.2+ KB
